# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Mulle/Desktop/Python-Dorset/Week 11/BTC-2020min.csv')
df
# Out:
#               unix                 date   symbol      open      high  \
# 0       1609459140  2020-12-31 23:59:00  BTC/USD  28982.44  29024.59
# 1       1609459080  2020-12-31 23:58:00  BTC/USD  29044.79  29048.62
# 2       1609459020  2020-12-31 23:57:00  BTC/USD  29039.53  29048.63
# 3       1609458960  2020-12-31 23:56:00  BTC/USD  29052.02  29059.42
# 4       1609458900  2020-12-31 23:55:00  BTC/USD  29036.10  29052.02
# ...            ...                  ...      ...       ...       ...
# 487717  1577837100  2020-01-01 00:05:00  BTC/USD   7156.52   7159.51
# 487718  1577837040  2020-01-01 00:04:00  BTC/USD   7158.50   7158.50
# 487719  1577836980  2020-01-01 00:03:00  BTC/USD   7158.82   7158.82
# 487720  1577836920  2020-01-01 00:02:00  BTC/USD   7158.82   7158.82
# 487721  1577836860  2020-01-01 00:01:00  BTC/USD   7161.51   7161.51
#
#              low     close  Volume BTC     Volume USD
# 0       28969.83  28992.79    5.897679  170990.182941
# ...

# %% [markdown]
# 1- Delete UNIX

# %%
df = df.drop(columns="unix")
df.head()
# Out:
#                   date   symbol      open      high       low     close  \
# 0  2020-12-31 23:59:00  BTC/USD  28982.44  29024.59  28969.83  28992.79
# 1  2020-12-31 23:58:00  BTC/USD  29044.79  29048.62  29000.12  29000.12
# 2  2020-12-31 23:57:00  BTC/USD  29039.53  29048.63  29023.26  29044.79
# 3  2020-12-31 23:56:00  BTC/USD  29052.02  29059.42  29039.28  29039.53
# 4  2020-12-31 23:55:00  BTC/USD  29036.10  29052.02  29025.78  29052.02
#
#    Volume BTC     Volume USD
# 0    5.897679  170990.182941
# 1   20.362289  590508.837815
# 2   14.503728  421257.721488
# 3    2.707583   78626.925850
# 4    7.631439  221708.705383

# %% [markdown]
# 2- Make date as index

# %%
df.set_index("date")
# Out:
#                       symbol      open      high       low     close  \
# date
# 2020-12-31 23:59:00  BTC/USD  28982.44  29024.59  28969.83  28992.79
# 2020-12-31 23:58:00  BTC/USD  29044.79  29048.62  29000.12  29000.12
# 2020-12-31 23:57:00  BTC/USD  29039.53  29048.63  29023.26  29044.79
# 2020-12-31 23:56:00  BTC/USD  29052.02  29059.42  29039.28  29039.53
# 2020-12-31 23:55:00  BTC/USD  29036.10  29052.02  29025.78  29052.02
# ...                      ...       ...       ...       ...       ...
# 2020-01-01 00:05:00  BTC/USD   7156.52   7159.51   7150.10   7158.50
# 2020-01-01 00:04:00  BTC/USD   7158.50   7158.50   7154.97   7157.20
# 2020-01-01 00:03:00  BTC/USD   7158.82   7158.82   7156.90   7156.90
# 2020-01-01 00:02:00  BTC/USD   7158.82   7158.82   7158.82   7158.82
# 2020-01-01 00:01:00  BTC/USD   7161.51   7161.51   7155.09   7161.20
#
#                      Volume BTC     Volume USD
# date
# 2020-12-31 23:59:00    5.897679  170990.182941
# ...

# %% [markdown]
# 3- Make a single date dataframe

# %%
df['single date'] = df['date'].str.split(' ')[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Mulle\Desktop\Python-Dorset\Week 11\BTC.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mulle/Desktop/Python-Dorset/Week%2011/BTC.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df['single date'] = df['date'].str.split(' ')[0]
#
# File c:\Users\Mulle\anaconda3\envs\py38\lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File c:\Users\Mulle\anaconda3\envs\py38\lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
#    4135     Add series to DataFrame in specified column.
#    4136
#    (...)
#    4141     ensure homogeneity.
#    4142     """
# ...
