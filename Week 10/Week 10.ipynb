# %% [markdown]
# 1.	Import the necessary libraries
# 2.	Import the dataset from this address.

# %%
import pandas as pd

# %% [markdown]
# 3.	Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv("C:\\Users\\Mulle\\Desktop\\AI\\Week 10\\US_Baby_Names_right.csv")

# %% [markdown]
# 4.	See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# 5.	Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(columns=["Unnamed: 0", "Id"], axis=1 )
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# 6.	Is there more male or female names in the dataset?

# %%
m = 0
f = 0
for genders in baby_names["Gender"]:
    if(genders == "M") : 
        m += 1
    else:
        f = 0
if(m>f):
    print("male")
else:
    print("female")
# Out:
# male

# %% [markdown]
# 7.	Group the dataset by name and assign to names

# %%
names = baby_names.groupby('Name').sum() #dif between Count and sum()
names.iloc[:,0]
# Out:
# Name
# Aaban        7733801
# Aadan        7158061
# Aadarsh      1728030
# Aaden      555052029
# Aadhav        709606
#              ...
# Zyra        17538998
# Zyrah        5487073
# Zyren        5074229
# Zyria       29787029
# Zyriah      34146196
# Name: Unnamed: 0, Length: 17632, dtype: int64

# %% [markdown]
# 8.	How many different names exist in the dataset?

# %%
baby_names.Name.nunique()
# Out:
# 17632

# %% [markdown]
# 9.	What is the name with most occurrences?

# %%
baby_names.groupby('Name').Count.sum().sort_values(ascending=False)
# Out:
# Name
# Jacob         242874
# Emma          214852
# Michael       214405
# Ethan         209277
# Isabella      204798
#                ...
# Eniola             5
# Atlantis           5
# Marci              5
# Simarpreet         5
# Nita               5
# Name: Count, Length: 17632, dtype: int64

# %% [markdown]
# 10.	How many different names have the least occurrences?

# %%
(baby_names.Count == baby_names.Count.min()).sum()
# Out:
# 147086

# %% [markdown]
# 11.	What is the median name occurrence?

# %%
(baby_names.Count == baby_names.Count.median()).sum()
# Out:
# 36199

# %% [markdown]
# 12.	What is the standard deviation of names?

# %%
baby_names.groupby("Name").Count.sum().std()
# Out:
# 11006.069467891111

# %% [markdown]
# 13.	Get a summary with the mean, min, max, std and quartiles.

# %%
baby_names.describe()
# Out:
#          Unnamed: 0            Id          Year         Count
# count  1.016395e+06  1.016395e+06  1.016395e+06  1.016395e+06
# mean   2.830990e+06  2.830991e+06  2.009053e+03  3.485012e+01
# std    1.652476e+06  1.652476e+06  3.138293e+00  9.739735e+01
# min    1.134900e+04  1.135000e+04  2.004000e+03  5.000000e+00
# 25%    1.317326e+06  1.317328e+06  2.006000e+03  7.000000e+00
# 50%    2.811920e+06  2.811921e+06  2.009000e+03  1.100000e+01
# 75%    4.242554e+06  4.242556e+06  2.012000e+03  2.600000e+01
# max    5.647425e+06  5.647426e+06  2.014000e+03  4.167000e+03

# %% [markdown]
# S12_3 Filtering and Sorting Data

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# Step 2. Import the dataset from this address.

# %%
pd.read_csv("C:\\Users\\Mulle\\Desktop\\AI\\Week 10\\Euro_2012_stats_TEAM.csv")
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 3. Assign it to a variable called euro12.

# %%
euro12 = pd.read_csv("C:\\Users\\Mulle\\Desktop\\AI\\Week 10\\Euro_2012_stats_TEAM.csv")

# %% [markdown]
# Step 4. Select only the Goal column.

# %%
euro12.iloc[:,1]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step 5. How many team participated in the Euro2012?

# %%
euro12.Team.nunique()
# Out:
# 16

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
euro12.shape
euro12.shape[1] #colonnes
euro12.shape[0] #lignes
# Out:
# 16

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by = ['Red Cards', 'Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro12.groupby('Team')['Yellow Cards'].mean()
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %% [markdown]
# Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12['Goals'] > 5].iloc[:,:2]
# Out:
#         Team  Goals
# 5    Germany     10
# 7      Italy      6
# 10  Portugal      6
# 13     Spain     12

# %% [markdown]
# Step 11. Select the teams that start with G

# %%
euro12[euro12['Team'].str[0] == 'G']
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# Step 12. Select the first 7 columns

# %%
euro12.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %% [markdown]
# Step 13. Select all columns except the last 3.

# %%
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12['Team'].isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# S12_2 Wind Statistics

# %% [markdown]
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# Step 2. Import the dataset from this address

# %%
pd.read_csv("C:\\Users\\Mulle\\Desktop\\AI\\Week 10\\winddata.csv")
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
# 6574  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv("C:\\Users\\Mulle\\Desktop\\AI\\Week 10\\winddata.csv")
#data[["Yr", "Mo", "Dy", "RPT", "VAL", "ROS", "KIL", "SHA", "BIR", "DUB", "CLA", "MUL", "CLO", "BEL", "MAL"]] = data["Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL"].str.split("[ ]", expand = True).loc[:,:14]
#data = data.drop(columns=["Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL"], axis = 1)

data["Date"] = data[["Dy", "Mo","Yr"]].astype(str).agg('-'.join, axis=1)
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
# 6574  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL      Date
# 0     10.83  12.58  18.50  15.04    1-1-61
# ...

# %% [markdown]
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data[data['Yr'] > 23] = "19" + data[(data['Yr'] > 23) & (data.columns.values == "Yr")].astype(str)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Mulle\Desktop\AI\Week 10\Week 10.ipynb Cell 64 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Mulle/Desktop/AI/Week%2010/Week%2010.ipynb#Y155sZmlsZQ%3D%3D?line=0'>1</a> data[data['Yr'] > 23] = "19" + data[(data['Yr'] > 23) & (data.columns.values == "Yr")].astype(str)
#       <a href='vscode-notebook-cell:/c%3A/Users/Mulle/Desktop/AI/Week%2010/Week%2010.ipynb#Y155sZmlsZQ%3D%3D?line=1'>2</a> data
#
# File c:\Users\Mulle\anaconda3\envs\py38\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Mulle\anaconda3\envs\py38\lib\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
# ...

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %% [markdown]
# Step 6. Compute how many values are missing for each location over the entire record. They should be ignored in all calculations below.

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times. A single number for the entire dataset.

# %% [markdown]
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days A different set of numbers for each location.

# %% [markdown]
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day. A different set of numbers for each day.

# %% [markdown]
# Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.

# %% [markdown]
# Step 12. Downsample the record to a yearly frequency for each location.

# %% [markdown]
# Step 13. Downsample the record to a monthly frequency for each location.

# %% [markdown]
# Step 14. Downsample the record to a weekly frequency for each location.

# %% [markdown]
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.
